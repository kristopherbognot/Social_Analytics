# %%
# %matplotlib inline

# %%
#Dependencies
import pandas as pd
import tweepy
import json
import matplotlib.pyplot as plt
from config_twitter import consumer_key, consumer_secret, access_token, access_token_secret
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
#tweepy API Authentication

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
#BBC
target_user = "BBCWorld"

counter = 1

bbc_sentiments = []

oldest_tweet = None

bbc_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

#Loop through tweets
for tweet in bbc_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    bbc_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    
    counter += 1


bbc_sentiments_df = pd.DataFrame.from_dict(bbc_sentiments)
bbc_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.2263  Tue Aug 28 23:32:51 +0000 2018     0.192    0.808     0.000
# 1   -0.5994  Tue Aug 28 22:24:35 +0000 2018     0.302    0.698     0.000
# 2   -0.8176  Tue Aug 28 21:35:18 +0000 2018     0.572    0.289     0.139
# 3   -0.5106  Tue Aug 28 21:12:44 +0000 2018     0.350    0.650     0.000
# 4   -0.5994  Tue Aug 28 21:09:54 +0000 2018     0.302    0.698     0.000
#
#      Source                                               Text  Tweets Ago
# 0  BBCWorld  Chemnitz protests: Far-right on march in east ...           1
# 1  BBCWorld  Puerto Rico increases Hurricane Maria death to...           2
# 2  BBCWorld  Didi blames 'ignorance and pride' for carpool ...           3
# 3  BBCWorld  Canada police arrest teen suspected in German ...           4
# 4  BBCWorld  Scallop war: French and British boats clash in...           5

# %%
#CSB NEWS
target_user = "CBSNews"

counter = 1

cbs_sentiments = []

oldest_tweet = None

cbs_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

#Loop through tweets
for tweet in cbs_public_tweets:
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    cbs_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})

    counter += 1


cbs_sentiments_df = pd.DataFrame.from_dict(cbs_sentiments)
cbs_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.2732  Tue Aug 28 23:20:51 +0000 2018     0.143    0.757     0.100
# 1    0.0000  Tue Aug 28 23:09:47 +0000 2018     0.000    1.000     0.000
# 2    0.0000  Tue Aug 28 23:07:09 +0000 2018     0.000    1.000     0.000
# 3    0.1779  Tue Aug 28 23:05:53 +0000 2018     0.000    0.922     0.078
# 4    0.2263  Tue Aug 28 23:05:09 +0000 2018     0.065    0.829     0.106
#
#     Source                                               Text  Tweets Ago
# 0  CBSNews  Hurricane Maria now stands as one of the deadl...           1
# 1  CBSNews  WATCH NOW: The governor of Puerto Rico @ricard...           2
# 2  CBSNews  RT @DavidBegnaud: We are live now with the Gov...           3
# 3  CBSNews  RT @CBSEveningNews: Her spunky spirit and danc...           4
# 4  CBSNews  Thousands pay their respects to the “Queen of ...           5

# %%
#CNN
target_user = "CNN"

counter = 1

cbs_sentiments = []

oldest_tweet = None

cbs_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

#Loop through tweets
for tweet in cbs_public_tweets:
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    cbs_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})

    counter += 1


cnn_sentiments_df = pd.DataFrame.from_dict(cbs_sentiments)
cnn_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.5563  Tue Aug 28 23:41:01 +0000 2018     0.159    0.841     0.000
# 1    0.0000  Tue Aug 28 23:31:05 +0000 2018     0.149    0.702     0.149
# 2    0.0000  Tue Aug 28 23:27:07 +0000 2018     0.000    1.000     0.000
# 3   -0.5423  Tue Aug 28 23:21:13 +0000 2018     0.241    0.759     0.000
# 4    0.4215  Tue Aug 28 23:21:05 +0000 2018     0.000    0.865     0.135
#
#   Source                                               Text  Tweets Ago
# 0    CNN  Air pollution could be more damaging to our he...           1
# 1    CNN  Supreme Court nominee Brett Kavanaugh will be ...           2
# 2    CNN  RT @OutFrontCNN: "One of the lessons I've lear...           3
# 3    CNN  Arizona polls to close on time after Election ...           4
# 4    CNN  Nearly 2.3 million cases of chlamydia, gonorrh...           5

# %%
#Fox News
target_user = "FoxNews"

counter = 1

cbs_sentiments = []

oldest_tweet = None

cbs_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

#Loop through tweets
for tweet in cbs_public_tweets:
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    cbs_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})

    counter += 1


fox_sentiments_df = pd.DataFrame.from_dict(cbs_sentiments)
fox_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.5719  Tue Aug 28 23:38:00 +0000 2018     0.171    0.829     0.000
# 1    0.0258  Tue Aug 28 23:34:20 +0000 2018     0.000    0.922     0.078
# 2   -0.5267  Tue Aug 28 23:28:45 +0000 2018     0.238    0.671     0.091
# 3   -0.1779  Tue Aug 28 23:20:50 +0000 2018     0.135    0.759     0.105
# 4    0.0000  Tue Aug 28 23:19:03 +0000 2018     0.000    1.000     0.000
#
#     Source                                               Text  Tweets Ago
# 0  FoxNews  .@MZHemingway on NC redistricting ruling: "It ...           1
# 1  FoxNews  Brett Kavanaugh backed by Bob Bennett, Bill Cl...           2
# 2  FoxNews  Toddler's death after leaving immigration faci...           3
# 3  FoxNews  .@USCG and @USNavy bomb technicians are workin...           4
# 4  FoxNews  Google CEO slammed by lawmakers for declining ...           5

# %%
#New York Times
target_user = "nytimes"

counter = 1

cbs_sentiments = []

oldest_tweet = None

cbs_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

#Loop through tweets
for tweet in cbs_public_tweets:
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    cbs_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})

    counter += 1


nyt_sentiments_df = pd.DataFrame.from_dict(cbs_sentiments)
nyt_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.2500  Tue Aug 28 23:41:02 +0000 2018     0.091    0.909     0.000
# 1   -0.2023  Tue Aug 28 23:32:06 +0000 2018     0.193    0.676     0.132
# 2    0.7004  Tue Aug 28 23:17:47 +0000 2018     0.072    0.719     0.209
# 3    0.3254  Tue Aug 28 23:17:04 +0000 2018     0.000    0.896     0.104
# 4    0.0000  Tue Aug 28 23:12:13 +0000 2018     0.000    1.000     0.000
#
#     Source                                               Text  Tweets Ago
# 0  nytimes  RT @joshbarone: Three male principal dancers a...           1
# 1  nytimes  Peter Polansky may be tennis’s luckiest loser....           2
# 2  nytimes  RT @shearm: Also, @realDonaldTrump noted that ...           3
# 3  nytimes  RT @shearm: UPDATED SCOOP: I’ve added a bit mo...           4
# 4  nytimes  First election results are coming in from Flor...           5

# %%
#Combine into one df
cb_news = pd.concat([bbc_sentiments_df, cbs_sentiments_df, cnn_sentiments_df, fox_sentiments_df, nyt_sentiments_df], ignore_index=True)
cb_news = cb_news[["Source", "Date", "Text", "Positive", "Neutral", "Negative", "Compound", "Tweets Ago"]]

# Output
cb_news.to_csv("SavedFiles/News_Mood.csv", encoding='utf-8', index=False)

# %%
bbc_com = cb_news.loc[cb_news["Source"] == "BBCWorld"]["Compound"]
bbc_tweets = cb_news.loc[cb_news["Source"] == "BBCWorld"]["Tweets Ago"]

cbs_com = cb_news.loc[cb_news["Source"] == "CBSNews"]["Compound"]
cbs_tweets = cb_news.loc[cb_news["Source"] == "CBSNews"]["Tweets Ago"]

cnn_com = cb_news.loc[cb_news["Source"] == "CNN"]["Compound"]
cnn_tweets = cb_news.loc[cb_news["Source"] == "CNN"]["Tweets Ago"]

fox_com = cb_news.loc[cb_news["Source"] == "FoxNews"]["Compound"]
fox_tweets = cb_news.loc[cb_news["Source"] == "FoxNews"]["Tweets Ago"]

nyt_com = cb_news.loc[cb_news["Source"] == "nytimes"]["Compound"]
nyt_tweets = cb_news.loc[cb_news["Source"] == "nytimes"]["Tweets Ago"]

#Setting Subplot for visual
fig, ax=plt.subplots()

# Plot the points gathered above
ax.scatter(bbc_tweets, bbc_com, s=75, marker ="o", color="lightskyblue", alpha=0.75, edgecolors="black")
ax.scatter(cbs_tweets, cbs_com, s=75, marker ="o", color="green", alpha=0.75, edgecolors="black")
ax.scatter(cnn_tweets, cnn_com, s=75, marker ="o", color="red", alpha=0.75, edgecolors="black")
ax.scatter(fox_tweets, fox_com, s=75, marker ="o", color="blue", alpha=0.75, edgecolors="black")
ax.scatter(nyt_tweets, nyt_com, s=75, marker ="o", color="yellow", alpha=0.75, edgecolors="black")

ax.set_xlim(100,0)
ax.set_ylim(-1, 1)
ax.set_facecolor("lavender")


# Set the grid lines behind the plots, remove unneccessary spines, and set tickmarks
ax.set_axisbelow(True)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_yticks([-1.0, -0.50, 0.0, 0.50, 1.00])
plt.tick_params(bottom=False, left=False)

ax.grid(color="white")

# Label the scatterplot
plt.title("Sentiment Analysis of Media Tweets (8/27/18)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

# Incorporate a text label regarding circle size

bbc = plt.scatter([],[], s=75, marker = "o", color = "lightskyblue", edgecolors="black")
cbs = plt.scatter([],[], s=75, marker = "o", color = "green", edgecolors="black")
cnn = plt.scatter([],[], s=75, marker = "o", color = "red", edgecolors="black")
fox = plt.scatter([],[], s=75, marker = "o", color = "blue", edgecolors="black")
ny_times = plt.scatter([],[], s=75, marker = "o", color = "gold", edgecolors="black")

# Create a legend
plt.legend((bbc, cbs, cnn, fox, ny_times), ("BBC", "CBS", "CNN", "Fox", "NY Times"), frameon=False, title="Media Sources", bbox_to_anchor=(1.01, 1))

#Set this so output file does not cut off legend
fig.tight_layout()

# Export graph for presentation
plt.savefig("SavedFiles/Sentiment_Analysis_Tweets.png")

plt.show()

# %%
#Setting Subplot for visual
fig, ax=plt.subplots()

#Collect chart values using loc for each news outlet
bbc_com_mean = cb_news.loc[cb_news["Source"] == "BBCWorld"]["Compound"].mean()
cbs_com_mean = cb_news.loc[cb_news["Source"] == "CBSNews"]["Compound"].mean()
cnn_com_mean = cb_news.loc[cb_news["Source"] == "CNN"]["Compound"].mean()
fox_com_mean = cb_news.loc[cb_news["Source"] == "FoxNews"]["Compound"].mean()
nyt_com_mean = cb_news.loc[cb_news["Source"] == "nytimes"]["Compound"].mean()

# data looks better without clutter

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tick_params(bottom=False, left=False) 

ax.set_facecolor("lavender")

#Create bar chart from values gathered above
plt.bar("BBC", bbc_com_mean, color ="lightskyblue", edgecolor="grey", align="center")
plt.bar("CBS", cbs_com_mean, color ="green", edgecolor="grey", align="center")
plt.bar("CNN", cnn_com_mean, color ="red", edgecolor="grey", align="center")
plt.bar("Fox", fox_com_mean, color ="blue", edgecolor="grey", align="center")
plt.bar("NYT", nyt_com_mean, color ="gold", edgecolor="grey", align="center")

plt.title("Overall Media Sentiment Based on Twitter (8/27/18)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    va = 'bottom'

    # If value of bar is negative: Place label below bar
    if y_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        va = 'top'

    # Use Y value as label and format number with one decimal place
    label = "{:.2f}".format(y_value)

    # Create annotation
    plt.annotate(
        label,
        (x_value, y_value),
        xytext=(0, space),
        textcoords="offset points",
        ha='center',
        va=va)
    
#Set this so output file does not cut off legend
fig.tight_layout()

# Export graph for presentation
plt.savefig("SavedFiles/Overall_Media_Sentiment.png")

plt.show()
